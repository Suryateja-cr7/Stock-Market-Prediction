# %% [markdown]
# # Simple Stock Charts

# %% [markdown]
# ## Types of Stock Charts

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# fix_yahoo_finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'AAPL'
start = '2018-12-01'
end = '2019-01-01'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-12-03  46.115002  46.235001  45.302502  46.205002  44.406498  163210000
# 2018-12-04  45.237499  45.597500  44.067501  44.172501  42.453110  165377200
# 2018-12-06  42.939999  43.695000  42.605000  43.680000  41.979771  172393600
# 2018-12-07  43.372501  43.622501  42.075001  42.122501  40.482895  169126400
# 2018-12-10  41.250000  42.522499  40.832500  42.400002  40.749596  248104000

# %% [markdown]
# ## Line Charts

# %%
plt.figure(figsize=(12,8))
plt.plot(df['Adj Close'])
plt.title("Stock Line Chart")
plt.legend(loc='best')
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## High Low Close Bar Stock Chart (HLC)

# %% [markdown]
# https://stackoverflow.com/questions/44810875/how-to-draw-a-classic-stock-chart-with-matplotlib

# %% [markdown]
# ## Open High Low Close Bar Stock Chart (OHLC)

# %%
import chart_studio.tools as tls

tls.set_credentials_file(username='suryacr7', api_key='z2ixvaIpc1pvOQzw9lCD')
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

# Plot OHLC Bar Chart
trace = go.Ohlc(x=df['12-2018'].index,
                open=df['12-2018'].Open,
                high=df['12-2018'].High,
                low=df['12-2018'].Low,
                close=df['12-2018'].Close)
data = [trace]
iplot(data, filename='simple_ohlc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '12-2018'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 8
#       5 from plotly.offline import init_notebook_mode, iplot
#       7 # Plot OHLC Bar Chart
# ----> 8 trace = go.Ohlc(x=df['12-2018'].index,
#       9                 open=df['12-2018'].Open,
#      10                 high=df['12-2018'].High,
#      11                 low=df['12-2018'].Low,
#      12                 close=df['12-2018'].Close)
#      13 data = [trace]
#      14 iplot(data, filename='simple_ohlc')
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: '12-2018'

# %%
py.iplot(data)

# %% [markdown]
# ## Japanese Candlesticks Charts

# %% [markdown]
# Learn about candlestick:
#
# https://www.quantinsti.com/blog/candlestick-patterns-meaning
#
# https://www.investopedia.com/trading/candlestick-charting-what-is-it/

# %%
from mpl_finance import candlestick_ohlc
from matplotlib import dates as mdates
import datetime as dt

# %%
# Converting date to pandas datetime format
dfc = df.copy()
dfc = dfc.reset_index()
dfc['Date'] = mdates.date2num(dfc['Date'].astype(dt.date))
dfc.head()

# %%
fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
candlestick_ohlc(ax1,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax1.xaxis_date()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax1.set_title('Stock '+ symbol +' Closing Price')
ax1.set_ylabel('Price')
ax1.legend(loc='best')

# %%
# Plot Candlestick Chart
trace = go.Candlestick(x=df['12-2018'].index,
                open=df['12-2018'].Open,
                high=df['12-2018'].High,
                low=df['12-2018'].Low,
                close=df['12-2018'].Close)

data = [trace]
iplot(data, filename='simple_ohlc')

# %% [markdown]
# ## Point and Figure Chart

# %% [markdown]
# https://github.com/pviglucci/pypf

# %%
from pypf.chart import PFChart
from pypf.instrument import YahooSecurity
i = YahooSecurity(symbol, force_download, force_cache, period, debug)
c = PFChart(i, box_size, duration, interval, method, reversal, style, trend_lines, debug)
c.create_chart()
print(c.chart)

# %% [markdown]
# ## Market Profile Stock Charts

# %% [markdown]
# https://github.com/bfolkens/py-market-profile

# %%
from market_profile import MarketProfile

# %%
mp = MarketProfile(df, tick_size=1)
mp_slice = mp[df.index.max() - pd.Timedelta(6.5, 'd'):df.index.max()]

# %%
data = mp_slice.profile
data.plot(kind='bar')
