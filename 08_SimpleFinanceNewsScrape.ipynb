# %% [markdown]
# # Simple Finance News Scrape

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "http://finance.google.com/finance/market_news?ei=IbdpWqiTEYWsugSGh4-4Ag"
html = requests.get(url)
soup = BeautifulSoup(html.content, "html.parser")

# %%
all_tables = soup.find_all('table')
all_tables
# Out:
# []

# %%
import newspaper

yahoo_finance_news = newspaper.build('https://finance.yahoo.com/')

# %%
for article in yahoo_finance_news.articles:
    print(article.url)

# %%
for category in yahoo_finance_news.category_urls():
    print(category)
# Out:
# https://finance.yahoo.com/
# https://www.yahoo.com
# https://guce.yahoo.com
# https://news.yahoo.com
# https://finance.yahoo.com/gainers
# https://finance.yahoo.com/most-active
# https://finance.yahoo.com/portfolios
# https://finance.yahoo.com/watchlists
# https://finance.yahoo.com/losers
# https://finance.yahoo.com/screener
# https://finance.yahoo.com
# https://finance.yahoo.com/calendar
# https://finance.yahoo.com/news
# https://finance.yahoo.com/crypto
# https://finance.yahoo.com/currencies
# https://finance.yahoo.com/commodities
# https://sports.yahoo.com
# https://finance.yahoo.com/videos
# https://finance.yahoo.com/recent-quotes
# https://finance.yahoo.com/etfs
# https://yahoo.uservoice.com
# https://finance.yahoo.com/mutualfunds

# %%
from newspaper import fulltext

html = requests.get('https://finance.yahoo.com/news/us-shale-apos-full-impact-114700505.html').text
text = fulltext(html)

# %%
text
# Out:
# 'Will be right back... Thank you for your patience. Our engineers are working quickly to resolve the issue.'

# %%
from newspaper import Article

url = 'https://finance.yahoo.com/news/intel-revenue-forecast-miss-data-211731829.html'
finance_article = Article(url)

# %%
finance_article.download()

# %%
finance_article.html
# Out:
# '<!doctype html><html  id=atomic class="NoJs Fz(62.5%) Pos(r) finance     desktop bktfinance-US-en-US-def ua-undefined ua-undefined" lang=en-US><head><script>\n        window.performance.mark(\'PageStart\');\n        (function(html){var c = document.documentElement.classList;c.add(\'JsEnabled\', \'jsenabled\');c.remove(\'NoJs\');})(document.documentElement);\n        /**\n        * Empty darlaOnready method, to avoid JS error.\n        * This can happen when Async Darla JS file is loaded earlier than Darla Proxy JS.\n        * This method will be overridden by Darla Proxy\n        */\n        window.darlaOnready = function() {};\n        </script><title>Intel Shares Slump After Giving Lackluster 2019 Forecast</title><meta http-equiv=content-type content="text/html; charset=utf-8"><meta http-equiv=x-dns-prefetch-control content=on><meta http-equiv=X-UA-Compatible content=chrome=1><meta name="oath:guce:consent-host" content="guce.yahoo.com"><meta name="news_keywords" content="Bloomberg, Intel Corp., data centers, Bob Swan, profit projections" /><meta name="twitter:title" content="Intel Shares Slump After Giving Lackluster 2019 Forecast" /><meta property="og:title" content="Intel Shares Slump After Giving Lackluster 2019 Forecast" /><meta property="og:url" content="https://finance.yahoo.com/news/intel-revenue-forecast-miss-data-211731829.html" /><meta property="al:android:url" content="yfinance://article/7d85f0f0-b967-311e-ab72-0c62c1460e10" /><link rel="amphtml" href="https://finance.yahoo.com/amphtml/news/intel-revenue-forecast-miss-data-211731829.html" /><meta name="twitter:description" content="The chipmaker&#x2019;s revenue and profit projections for the current quarter and the year fell short of analysts&#x2019; average estimates, sending shares tumbling in late trading on Thursday.  Intel, whose processors are the main component in most of the world&#x2019;s personal computers and servers, cited a slowdown in spending at large cloud-computing customers, softness in China and the impact of geopolitical concerns.  The lackluster outlook marked a change from recent quarters, when Intel has posted robust growth in its data-center unit as the biggest companies in technology, such as Amazon.com Inc., Alphabet Inc.&#x2019;s Google and Microsoft Corp., expanded their cloud offerings." /><meta name="description" content="The chipmaker&#x2019;s revenue and profit projections for the current quarter and the year fell short of analysts&#x2019; average estimates, sending shares tumbling in late trading on Thursday.  Intel, whose processors are the main component in most of the world&#x2019;s personal computers and servers, cited a slowdown in spending at large cloud-computing customers, softness in China and the impact of geopolitical concerns.  The lackluster outlook marked a change from recent quarters, when Intel has posted robust growth in its data-center unit as the biggest companies in technology, such as Amazon.com Inc., Alphabet Inc.&#x2019;s Google and Microsoft Corp., expanded their cloud offerings." /><meta property="og:description" content="The chipmaker&#x2019;s revenue and profit projections for the current quarter and the year fell short of analysts&#x2019; average estimates, sending shares tumbling in late trading on Thursday.  Intel, whose processors are the main component in most of the world&#x2019;s personal computers and servers, cited a slowdown in spending at large cloud-computing customers, softness in China and the impact of geopolitical concerns.  The lackluster outlook marked a change from recent quarters, when Intel has posted robust growth in its data-center unit as the biggest companies in technology, such as Amazon.com Inc., Alphabet Inc.&#x2019;s Google and Microsoft Corp., expanded their cloud offerings." /><meta property="al:android:app_name" content="Yahoo Finance" /><meta property="al:android:package" content="com.yahoo.mobile.client.android.finance" /><meta name="twitter:site" content="@YahooFinance ...

# %%
finance_article.parse()

# %%
finance_article.authors
# Out:
# ['Ian King']

# %%
finance_article.publish_date

# %%
finance_article.text
# Out:
# '(Bloomberg) -- Intel Corp. shares fell the most in six months after its first forecasts for 2019 sent a signal to investors that a torrent of spending on data centers, which has nourished sales and earnings growth for years, is beginning to dry up.\n\nThe chipmaker’s revenue and profit projections for the current quarter and the year fell short of analysts’ average estimates, sending shares tumbling in late trading on Thursday. Intel, whose processors are the main component in most of the world’s personal computers and servers, cited a slowdown in spending at large cloud-computing customers, softness in China and the impact of geopolitical concerns.\n\nShares tumbled as much as 8 percent, the most since July, to $45.75 Friday in New York, bucking a broader market rally. Several analysts cut their price targets and downgraded the stock.\n\nThe lackluster outlook marked a change from recent quarters, when Intel has posted robust growth in its data-center unit as the biggest companies in technology, such as Amazon.com Inc., Alphabet Inc.’s Google and Microsoft Corp., expanded their cloud offerings. Those clients have accumulated inventory and are now cutting orders while they work through their stockpiles, Chief Financial Officer Bob Swan said in an interview.\n\n“Weakness within data center was a surprise as this has been a consistent growth driver for the company,” said Logan Purk, an analyst at Edward D. Jones. “We believe demand has cooled following a significant ramp in spending last year.”\n\nSales in the December quarter were $18.7 billion, short of the average analyst estimate of $19 billion. Net income came in at $5.2 billion, or $1.12 a share, while analysts projected $1.17 a share. Revenue in the current period will be about $16 billion and profit will be 81 cents a share, Intel said Thursday in a statement. Analysts polled by Bloomberg had estimated sales of $17.3 billion and earnings of 96 cents a share.\n\nFor 2019, Intel predicted revenue of about $71.5 billion, missing average projections of $73 billion. While that would be a record for the company’s sales, it would represent the slowest annual growth rate since 2015.\n\nStory continues\n\nIntel has a market share of about 99 percent for chips that run servers, the machines that provide the backbone of the internet and corporate networks. In the fourth quarter, revenue from that business division rose 9 percent, a steep deceleration from the third quarter, when that unit’s sales notched up 26 percent. Aaron Rakers, an analyst at Wells Fargo, was looking for sales growth of 13 percent for the data-center group in the recent period.\n\nGlobal shipments of personal computers, the market that provides Intel with the majority of its profit, declined 4.3 percent in the fourth quarter, according to Gartner Inc., as political and economic uncertainty reduced consumer demand, even during the holiday season.\n\nStill, Intel’s division that makes PC processors saw sales improve in the period, even in a slowing market. Revenue rose 10 percent from a year earlier to $9.8 billion. While volumes were down, average selling prices rose for both desktop and laptop parts.\n\nThe company has recently struggled to transition its factory network to more advanced techniques. That left Intel short of capacity last year. In response, the company prioritized chips that it can charge more for -- server and high-end desktop processors -- causing shortages in some areas. That may have helped boost profit margins and caused customers to over-order, according to Sanford C. Bernstein analyst Stacy Rasgon.\n\nIntel initially sparked concern last year that it may be losing its edge in manufacturing when the Santa Clara, California-based company confirmed that it won’t mass-produce chips made with 10-nanometer technology until later this year. That revised schedule may put it behind rivals such as Taiwan Semiconductor Manufacturing Co.\n\nIntel’s manufacturing lead has helped relegate Advanced Mic ...

# %%
finance_article.top_image
# Out:
# 'https://s.yimg.com/ny/api/res/1.2/HxOwQoNb6bT0X5ddihA1sQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03OTk-/https://media.zenfs.com/en-US/homerun/bloomberg_technology_68/45aaf50879304cb0c30a9b063c807dec'

# %%
import nltk
# nltk.download('punkt')

finance_article.nlp()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[24], line 4
#       1 import nltk
#       2 # nltk.download('punkt')
# ----> 4 finance_article.nlp()
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/newspaper/article.py:361, in Article.nlp(self)
#     357 self.set_keywords(keyws)
#     359 max_sents = self.config.MAX_SUMMARY_SENT
# --> 361 summary_sents = nlp.summarize(title=self.title, text=self.text, max_sents=max_sents)
#     362 summary = '\n'.join(summary_sents)
#     363 self.set_summary(summary)
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/newspaper/nlp.py:45, in summarize(url, title, text, max_sents)
#      42     return []
#      44 summaries = []
# ---> 45 sentences = split_sentences(text)
#      46 keys = keywords(text)
#      47 titleWords = split_words(title)
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/newspaper/nlp.py:157, in split_sentences(text)
#     154 """Split a large string into sentences
#     155 """
#     156 import nltk.data
# --> 157 tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
#     159 sentences = tokenizer.tokenize(text)
#     160 sentences = [x.replace('\n', '') for x in sentences if len(x) > 10]
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/nltk/data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/nltk/data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File ~/anaconda3/envs/ml/lib/python3.9/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/home/surya/nltk_data'
#     - '/home/surya/anaconda3/envs/ml/nltk_data'
#     - '/home/surya/anaconda3/envs/ml/share/nltk_data'
#     - '/home/surya/anaconda3/envs/ml/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %%
finance_article.keywords
# Out:
# ['demand',
#  'intel',
#  'profit',
#  'rose',
#  'company',
#  'quarter',
#  'sales',
#  'drop',
#  'slows',
#  'processors',
#  'billion',
#  'miss',
#  'revenue',
#  'datacenter',
#  'chips',
#  'shares']

# %%
finance_article.summary
# Out:
# 'Sales in the December quarter were $18.7 billion, short of the average analyst estimate of $19 billion.\nRevenue in the current period will be about $16 billion and profit will be 81 cents a share, Intel said Thursday in a statement.\nAnalysts polled by Bloomberg had estimated sales of $17.3 billion and earnings of 96 cents a share.\nIn the fourth quarter, Intel said net income was $5.2 billion, or $1.12 a share.\nStill, Intel’s division that makes PC processors saw sales improve in the period, even in a slowing market.'
